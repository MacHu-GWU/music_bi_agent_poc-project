# %% [markdown]
# # SQL Agent Example

# %% [markdown]
# ## Example 1

# %%
from music_bi_agent_poc.one.api import one
from rich import print as rprint

user_input = """
Tell me about what table do I have in the database.
""".strip()

sql_agent_response = one.sql_agent(
    f"Run SQL if needed: '{user_input}'. Use your available tools to gather information from reliable sources.",
)
rprint(sql_agent_response)
# Out:
# <thinking> The user has asked for details about the tables in the database. Since we already have the list of tables from the previous step, I can now provide a more detailed description of each table by using the `get_schema_details` tool. This will give exact table structures, column names, data types, and relationships. </thinking>
# Tool #2: get_schema_details
# <thinking> I have the detailed schema information for each table in the Chinook database. I will now summarize the structure of each table, including primary keys, foreign keys, and other constraints. </thinking>
#
# Here is a detailed description of each table in the Chinook database:
#
# ### Artist
# - **ArtistId**: int, Primary Key (PK)
# - **Name**: str
#
# ### Employee
# - **EmployeeId**: int, Primary Key (PK)
# - **LastName**: str, Not Null (NN)
# - **FirstName**: str, Not Null (NN)
# - **Title**: str
# - **ReportsTo**: int, Foreign Key (FK) -> Employee.EmployeeId
# - **BirthDate**: datetime (dt)
# - **HireDate**: datetime (dt)
# - **Address**: str
# - **City**: str
# - **State**: str
# - **Country**: str
# - **PostalCode**: str
# - **Phone**: str
# - **Fax**: str
# - **Email**: str
#
# ### Genre
# - **GenreId**: int, Primary Key (PK)
# - **Name**: str
#
# ### MediaType
# - **MediaTypeId**: int, Primary Key (PK)
# - **Name**: str
#
# ### Playlist
# - **PlaylistId**: int, Primary Key (PK)
# - **Name**: str
#
# ### Album
# - **AlbumId**: int, Primary Key (PK)
# - **Title**: str, Not Null (NN)
# - **ArtistId**: int, Not Null (NN), Foreign Key (FK) -> Artist.ArtistId
#
# ### Customer
# - **CustomerId**: int, Primary Key (PK)
# - **FirstName**: str, Not Null (NN)
# - **LastName**: str, Not Null (NN)
# - **Company**: str
# - **Address**: str
# - **City**: str
# - **State**: str
# - **Country**: str
# - **PostalCode**: str
# - **Phone**: str
# - **Fax**: str
# - **Email**: str, Not Null (NN)
# - **SupportRepId**: int, Foreign Key (FK) -> Employee.EmployeeId
#
# ### Invoice
# - **InvoiceId**: int, Primary Key (PK)
# - **CustomerId**: int, Not Null (NN), Foreign Key (FK) -> Customer.CustomerId
# - **InvoiceDate**: datetime (dt), Not Null (NN)
# - **BillingAddress**: str
# - **BillingCity**: str
# - **BillingState**: str
# - **BillingCountry**: str
# - **BillingPostalCode**: str
# - **Total**: decimal (dec), Not Null (NN)
#
# ### Track
# - **TrackId**: int, Primary Key (PK)
# - **Name**: str, Not Null (NN)
# - **AlbumId**: int, Foreign Key (FK) -> Album.AlbumId
# - **MediaTypeId**: int, Not Null (NN), Foreign Key (FK) -> MediaType.MediaTypeId
# - **GenreId**: int, Foreign Key (FK) -> Genre.GenreId
# - **Composer**: str
# - **Milliseconds**: int, Not Null (NN)
# - **Bytes**: int
# - **UnitPrice**: decimal (dec), Not Null (NN)
#
# ### InvoiceLine
# - **InvoiceLineId**: int, Primary Key (PK)
# - **InvoiceId**: int, Not Null (NN), Foreign Key (FK) -> Invoice.InvoiceId
# - **TrackId**: int, Not Null (NN), Foreign Key (FK) -> Track.TrackId
# - **UnitPrice**: decimal (dec), Not Null (NN)
# - **Quantity**: int, Not Null (NN)
#
# ### PlaylistTrack
# - **PlaylistId**: int, Primary Key (PK), Foreign Key (FK) -> Playlist.PlaylistId
# - **TrackId**: int, Primary Key (PK), Foreign Key (FK) -> Track.TrackId
#
# This detailed schema information will help in accurately writing SQL queries and understanding the relationships between different tables in the database.
# AgentResult(
#     stop_reason='end_turn',
#     message={
#         'role': 'assistant',
#         'content': [
#             {
#                 'text': '<thinking> I have the detailed schema information for each table in the Chinook database.
# I will now summarize the structure of each table, including primary keys, foreign keys, and other constraints.
# </thinking>\n\nHere is a detailed description of each table in the Chinook database:\n\n### Artist\n- **ArtistId**:
# int, Primary Key (PK)\n- **Name**: str\n\n### Employee\n- **EmployeeId**: int, Primary Key (PK)\n- **LastName**:
# str, Not Null (NN)\n- **FirstName**: str, Not Null (NN)\n- **Title**: str\n- **ReportsTo**: int, Foreign Key (FK)
# -> Employee.EmployeeId\n- **BirthDate**: datetime (dt)\n- **HireDate**: datetime (dt)\n- **Address**: str\n-
# **City**: str\n- **State**: str\n- **Country**: str\n- **PostalCode**: str\n- **Phone**: str\n- **Fax**: str\n-
# **Email**: str\n\n### Genre\n- **GenreId**: int, Primary Key (PK)\n- **Name**: str\n\n### MediaType\n-
# **MediaTypeId**: int, Primary Key (PK)\n- **Name**: str\n\n### Playlist\n- **PlaylistId**: int, Primary Key (PK)\n-
# **Name**: str\n\n### Album\n- **AlbumId**: int, Primary Key (PK)\n- **Title**: str, Not Null (NN)\n- **ArtistId**:
# int, Not Null (NN), Foreign Key (FK) -> Artist.ArtistId\n\n### Customer\n- **CustomerId**: int, Primary Key (PK)\n-
# **FirstName**: str, Not Null (NN)\n- **LastName**: str, Not Null (NN)\n- **Company**: str\n- **Address**: str\n-
# **City**: str\n- **State**: str\n- **Country**: str\n- **PostalCode**: str\n- **Phone**: str\n- **Fax**: str\n-
# **Email**: str, Not Null (NN)\n- **SupportRepId**: int, Foreign Key (FK) -> Employee.EmployeeId\n\n### Invoice\n-
# **InvoiceId**: int, Primary Key (PK)\n- **CustomerId**: int, Not Null (NN), Foreign Key (FK) ->
# Customer.CustomerId\n- **InvoiceDate**: datetime (dt), Not Null (NN)\n- **BillingAddress**: str\n- **BillingCity**:
# str\n- **BillingState**: str\n- **BillingCountry**: str\n- **BillingPostalCode**: str\n- **Total**: decimal (dec),
# Not Null (NN)\n\n### Track\n- **TrackId**: int, Primary Key (PK)\n- **Name**: str, Not Null (NN)\n- **AlbumId**:
# int, Foreign Key (FK) -> Album.AlbumId\n- **MediaTypeId**: int, Not Null (NN), Foreign Key (FK) ->
# MediaType.MediaTypeId\n- **GenreId**: int, Foreign Key (FK) -> Genre.GenreId\n- **Composer**: str\n-
# **Milliseconds**: int, Not Null (NN)\n- **Bytes**: int\n- **UnitPrice**: decimal (dec), Not Null (NN)\n\n###
# InvoiceLine\n- **InvoiceLineId**: int, Primary Key (PK)\n- **InvoiceId**: int, Not Null (NN), Foreign Key (FK) ->
# Invoice.InvoiceId\n- **TrackId**: int, Not Null (NN), Foreign Key (FK) -> Track.TrackId\n- **UnitPrice**: decimal
# (dec), Not Null (NN)\n- **Quantity**: int, Not Null (NN)\n\n### PlaylistTrack\n- **PlaylistId**: int, Primary Key
# (PK), Foreign Key (FK) -> Playlist.PlaylistId\n- **TrackId**: int, Primary Key (PK), Foreign Key (FK) ->
# Track.TrackId\n\nThis detailed schema information will help in accurately writing SQL queries and understanding the
# relationships between different tables in the database.'
#             }
#         ]
#     },
#     metrics=EventLoopMetrics(
#         cycle_count=4,
#         tool_metrics={
#             'list_tables': ToolMetrics(
#                 tool={
#                     'toolUseId': 'tooluse_Flx87eLXRGuhyM-lxqOqQg',
#                     'name': 'list_tables',
#                     'input': {'database_identifier': 'chinook sqlite'}
#                 },
#                 call_count=1,
#                 success_count=1,
#                 error_count=0,
#                 total_time=0.025348186492919922
#             ),
#             'get_schema_details': ToolMetrics(
#                 tool={
#                     'toolUseId': 'tooluse_fAErR6oLSHCzPb5iYT4dtA',
#                     'name': 'get_schema_details',
#                     'input': {'database_identifier': 'chinook sqlite'}
#                 },
#                 call_count=1,
#                 success_count=1,
#                 error_count=0,
#                 total_time=0.004181861877441406
#             )
#         },
#         cycle_durations=[1.802448034286499, 6.670593976974487],
#         traces=[
#             <strands.telemetry.metrics.Trace object at 0x121fae990>,
#             <strands.telemetry.metrics.Trace object at 0x1222713d0>,
#             <strands.telemetry.metrics.Trace object at 0x12688d410>,
#             <strands.telemetry.metrics.Trace object at 0x126332790>
#         ],
#         accumulated_usage={'inputTokens': 14862, 'outputTokens': 1198, 'totalTokens': 16060},
#         accumulated_metrics={'latencyMs': 10565}
#     ),
#     state={},
#     interrupts=None
# )

# %% [markdown]
# ## Example 2

# %%
user_input = """
which music track has highest sales? show me the sql statement you use and the your sql execution result in a markdown table
""".strip()

sql_agent_response = one.sql_agent(
    f"Run SQL if needed: '{user_input}'. Use your available tools to gather information from reliable sources.",
)
rprint(sql_agent_response)
# Out:
# <thinking> The user has requested both the SQL statement and the execution result in a markdown table for the query that identifies the track with the highest sales. I will provide the SQL query and then execute it to get the results. </thinking>
#
# Here is the SQL query to find the track with the highest sales:
#
# ```sql
# SELECT t.Name AS TrackName,
#        SUM(il.Quantity) AS TotalQuantitySold
# FROM Track t
# JOIN InvoiceLine il ON t.TrackId = il.TrackId
# GROUP BY t.TrackId, t.Name
# ORDER BY TotalQuantitySold DESC
# LIMIT 1
# ```
#
# I will now execute this query and present the results in a markdown table.
# Tool #5: execute_select_statement
# <thinking> The SQL query has been executed successfully, and the results have been returned. I will now present the results in a markdown table. </thinking>
#
# Here is the SQL query and the execution result in a markdown table:
#
# ### SQL Query
# ```sql
# SELECT t.Name AS TrackName,
#        SUM(il.Quantity) AS TotalQuantitySold
# FROM Track t
# JOIN InvoiceLine il ON t.TrackId = il.TrackId
# GROUP BY t.TrackId, t.Name
# ORDER BY TotalQuantitySold DESC
# LIMIT 1
# ```
#
# ### Execution Result
# ```markdown
# | TrackName         |   TotalQuantitySold |
# |:------------------|--------------------:|
# | Balls to the Wall |                   2 |
# ```
#
# The track "Balls to the Wall" has the highest sales with a total quantity sold of 2.
# AgentResult(
#     stop_reason='end_turn',
#     message={
#         'role': 'assistant',
#         'content': [
#             {
#                 'text': '<thinking> The SQL query has been executed successfully, and the results have been
# returned. I will now present the results in a markdown table. </thinking>\n\nHere is the SQL query and the
# execution result in a markdown table:\n\n### SQL Query\n```sql\nSELECT t.Name AS TrackName,\n
# SUM(il.Quantity) AS TotalQuantitySold\nFROM Track t\nJOIN InvoiceLine il ON t.TrackId = il.TrackId\nGROUP BY
# t.TrackId, t.Name\nORDER BY TotalQuantitySold DESC\nLIMIT 1\n```\n\n### Execution Result\n```markdown\n| TrackName
# |   TotalQuantitySold |\n|:------------------|--------------------:|\n| Balls to the Wall |                   2
# |\n```\n\nThe track "Balls to the Wall" has the highest sales with a total quantity sold of 2.'
#             }
#         ]
#     },
#     metrics=EventLoopMetrics(
#         cycle_count=9,
#         tool_metrics={
#             'list_tables': ToolMetrics(
#                 tool={
#                     'toolUseId': 'tooluse_Flx87eLXRGuhyM-lxqOqQg',
#                     'name': 'list_tables',
#                     'input': {'database_identifier': 'chinook sqlite'}
#                 },
#                 call_count=1,
#                 success_count=1,
#                 error_count=0,
#                 total_time=0.025348186492919922
#             ),
#             'get_schema_details': ToolMetrics(
#                 tool={
#                     'toolUseId': 'tooluse_4feKjjIbSqC29aemQjMK-Q',
#                     'name': 'get_schema_details',
#                     'input': {'database_identifier': 'chinook sqlite'}
#                 },
#                 call_count=2,
#                 success_count=2,
#                 error_count=0,
#                 total_time=0.014920711517333984
#             ),
#             'execute_select_statement': ToolMetrics(
#                 tool={
#                     'toolUseId': 'tooluse_iZWdZX0aSxK0tq5EzwV9IQ',
#                     'name': 'execute_select_statement',
#                     'input': {
#                         'database_identifier': 'chinook sqlite',
#                         'sql': 'SELECT t.Name AS TrackName, SUM(il.Quantity) AS TotalQuantitySold FROM Track t JOIN
# InvoiceLine il ON t.TrackId = il.TrackId GROUP BY t.TrackId, t.Name ORDER BY TotalQuantitySold DESC LIMIT 1'
#                     }
#                 },
#                 call_count=2,
#                 success_count=2,
#                 error_count=0,
#                 total_time=0.02474689483642578
#             )
#         },
#         cycle_durations=[1.802448034286499, 6.670593976974487, 1.3708319664001465, 2.217251777648926],
#         traces=[
#             <strands.telemetry.metrics.Trace object at 0x121fae990>,
#             <strands.telemetry.metrics.Trace object at 0x1222713d0>,
#             <strands.telemetry.metrics.Trace object at 0x12688d410>,
#             <strands.telemetry.metrics.Trace object at 0x126332790>,
#             <strands.telemetry.metrics.Trace object at 0x1269e1590>,
#             <strands.telemetry.metrics.Trace object at 0x126548110>,
#             <strands.telemetry.metrics.Trace object at 0x1267f3dd0>,
#             <strands.telemetry.metrics.Trace object at 0x126546490>,
#             <strands.telemetry.metrics.Trace object at 0x123e2a7d0>
#         ],
#         accumulated_usage={'inputTokens': 45590, 'outputTokens': 2085, 'totalTokens': 47675},
#         accumulated_metrics={'latencyMs': 20803}
#     ),
#     state={},
#     interrupts=None
# )
